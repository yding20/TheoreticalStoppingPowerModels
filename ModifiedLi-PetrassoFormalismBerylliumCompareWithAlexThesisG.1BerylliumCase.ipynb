# %%
# %matplotlib notebook
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import integrate
from LPModel import *

plt.figure(figsize=(7,5))
X_axis_15MeV = [15]
Y_axis_15MeV = [4.945, 5.044, 5.031, 4.54305, 5.12528, 4.70368, 4.68567, 4.74453, 4.717242,5.22628,4.897072, 4.916323,
               5.21098,5.3784, 4.658118, 4.57609, 4.343, 4.7131, 4.958335,4.60189,5.21939, 5.41826,4.83618,4.74665,
               4.665517,4.92778, 4.04098,4.53723,4.97978,4.79052,4.8449,4.76365, 5.08644, 4.5962, 4.864] 
Y_axis_15MeV = [x*1e-3 for x in Y_axis_15MeV]
#plt.scatter(X_axis_15MeV, Y_axis_15MaeV, alpha=0.5, label='Energy of Projectile = 15MeV')

X_axis_14MeV = [14]
Y_axis_14MeV = [5.271, 5.418, 5.3993, 4.9555, 5.45189, 5.06120, 5.0682, 5.11792, 5.044574, 5.62314, 5.336146,5.30738,
               5.52412,5.75839, 4.99284, 4.943647, 4.81208, 5.06443, 5.37175,4.93306,5.59985,5.76400,5.16197,5.098739,
               5.01059,5.26514, 4.44124,4.87619,5.315418,5.18446,5.25109,5.12155,5.41695,4.9505, 5.2667]
Y_axis_14MeV = [x*1e-3 for x in Y_axis_14MeV]
#plt.scatter(X_axis_15MeV, Y_axis_15MeV, alpha=0.5, label='Energy of Projectile = 15MeV')

X_axis_13MeV = [13]
Y_axis_13MeV = [5.581, 5.744, 5.770, 5.34554, 5.75404, 5.41399, 5.42668, 5.46638, 5.34281, 5.94589, 5.71877, 5.64631,
               5.82635, 6.1304, 5.29249, 5.289892, 5.26724, 5.362938,5.73559,5.23893,5.9568,6.08875,5.44506,5.37991,
               5.35585,5.57973,4.800,5.1747,5.654215,5.55332,5.6574,5.44012,5.74152,5.2758, 5.6379]
Y_axis_13MeV = [x*1e-3 for x in Y_axis_13MeV]
#plt.scatter(X_axis_15MeV, Y_axis_15MeV, alpha=0.5, label='Energy of Projectile = 15MeV')

X_axis_12MeV = [12]
Y_axis_12MeV = [5.9869, 6.214,6.1998, 5.8869, 6.25164, 5.88412, 5.89571, 5.90667, 5.72067, 6.42616, 6.28566, 6.12624,
               6.22360, 6.66119, 5.755099, 5.779801, 5.87158, 5.80922,6.2362,5.66147,6.4860,6.46614,5.88044,5.77726,
               5.79680,6.00302,5.2783,5.56347,6.08718,6.00506,6.165463,5.8925,6.20361,5.68, 6.1193]
Y_axis_12MeV = [x*1e-3 for x in Y_axis_12MeV]
#plt.scatter(X_axis_15MeV, Y_axis_15MeV, alpha=0.5, label='Energy of Projectile = 15MeV')


X_axis_11MeV = [11]
Y_axis_11MeV = [6.57254, 5.86660, 6.565405, 6.2920, 6.833152, 6.02946,6.9483, 6.47199, 6.82996, 7.06983]
Y_axis_11MeV = [x*1e-3 for x in Y_axis_11MeV]

X_axis_9MeV = [9]
Y_axis_9MeV = [8.07728, 7.226370, 8.13299,7.60918, 7.949213, 7.20663, 8.28731, 7.738537, 8.22958, 8.30584]
Y_axis_9MeV = [x*1e-3 for x in Y_axis_9MeV]

X_axis_7MeV = [7]
Y_axis_7MeV = [10.00046, 9.085747, 10.69648, 9.800813, 9.831137, 8.957169, 10.45235, 9.53893, 10.23784,10.2684]
Y_axis_7MeV = [x*1e-3 for x in Y_axis_7MeV]

X_axis_5MeV = [5]
Y_axis_5MeV = [12.931446, 11.779217, 14.22583, 13.325811,13.3419, 12.252742, 13.80537, 12.49942, 13.1676677, 13.823402]
Y_axis_5MeV = [x*1e-3 for x in Y_axis_5MeV]

X_axis_4MeV = [4]
Y_axis_4MeV = [15.20937, 14.276, 15.50665, 14.27657, 14.87421]
Y_axis_4MeV = [x*1e-3 for x in Y_axis_4MeV]

X_axis_3MeV = [3]
Y_axis_3MeV = [19.62428, 18.80287, 19.74369, 18.80287, 19.362112]
Y_axis_3MeV = [x*1e-3 for x in Y_axis_3MeV]

X_axis_2MeV = [2]
Y_axis_2MeV = [26.90279, 26.566189, 27.90519, 26.566189, 27.191565]
Y_axis_2MeV = [x*1e-3 for x in Y_axis_2MeV]

X_axis_1MeV = [1]
Y_axis_1MeV = [45.966740, 44.77960, 46.01940, 44.7796, 45.077191]
Y_axis_1MeV = [x*1e-3 for x in Y_axis_1MeV]

X_axis_06MeV = [0.6]
Y_axis_06MeV = [73]
Y_axis_06MeV = [x*1e-3 for x in Y_axis_06MeV]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [85]
Y_axis_05MeV = [x*1e-3 for x in Y_axis_05MeV]

X_axis_04MeV = [0.4]
Y_axis_04MeV = [94.24]
Y_axis_04MeV = [x*1e-3 for x in Y_axis_04MeV]

X_axis_02MeV = [0.2]
Y_axis_02MeV = [113.83]
Y_axis_02MeV = [x*1e-3 for x in Y_axis_02MeV]


X_average_15MeV = 15
Y_average_15MeV = np.sum(Y_axis_15MeV)/len(Y_axis_15MeV)
plt.errorbar(X_average_15MeV, Y_average_15MeV, np.std (Y_axis_15MeV),marker='o',capsize=3, 
             c = 'b', label='TD-OF-DFT',markersize='5')

X_average_14MeV = 14
Y_average_14MeV = np.sum(Y_axis_14MeV)/len(Y_axis_14MeV)
plt.errorbar(X_average_14MeV, Y_average_14MeV, np.std (Y_axis_14MeV),marker='o',capsize=3,c = 'b' ,markersize='5')

X_average_13MeV = 13
Y_average_13MeV = np.sum(Y_axis_13MeV)/len(Y_axis_13MeV)
plt.errorbar(X_average_13MeV, Y_average_13MeV, np.std (Y_axis_13MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_12MeV = 12
Y_average_12MeV = np.sum(Y_axis_12MeV)/len(Y_axis_12MeV)
plt.errorbar(X_average_12MeV, Y_average_12MeV, np.std (Y_axis_12MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_11MeV = 11
Y_average_11MeV = np.sum(Y_axis_11MeV)/len(Y_axis_11MeV)
plt.errorbar(X_average_11MeV, Y_average_11MeV, np.std (Y_axis_11MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_9MeV = 9
Y_average_9MeV = np.sum(Y_axis_9MeV)/len(Y_axis_9MeV)
plt.errorbar(X_average_9MeV, Y_average_9MeV, np.std (Y_axis_9MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_7MeV = 7
Y_average_7MeV = np.sum(Y_axis_7MeV)/len(Y_axis_7MeV)
plt.errorbar(X_average_7MeV, Y_average_7MeV, np.std (Y_axis_7MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_5MeV = 5
Y_average_5MeV = np.sum(Y_axis_5MeV)/len(Y_axis_5MeV)
plt.errorbar(X_average_5MeV, Y_average_5MeV, np.std (Y_axis_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_06MeV = 0.6
Y_average_06MeV = np.sum(Y_axis_06MeV)/len(Y_axis_06MeV)
plt.errorbar(X_average_06MeV, Y_average_06MeV, np.std (Y_axis_06MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_04MeV = 0.4
Y_average_04MeV = np.sum(Y_axis_04MeV)/len(Y_axis_04MeV)
plt.errorbar(X_average_04MeV, Y_average_04MeV, np.std (Y_axis_04MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_02MeV = 0.2
Y_average_02MeV = np.sum(Y_axis_02MeV)/len(Y_axis_02MeV)
plt.errorbar(X_average_02MeV, Y_average_02MeV, np.std (Y_axis_02MeV),marker='o',capsize=3,c = 'b', markersize='5')


PEnergy, StopPow = LP(1, 1,FieldDensity=1.84, FieldTem=32, FieldCharge=4, FieldMass=9, ProjE=16, ProjM=1, ProjC=1 )
PEnergy1, StopPow1 = LP(1, 0,FieldDensity=1.84, FieldTem=32, FieldCharge=4, FieldMass=9, ProjE=16, ProjM=1, ProjC=1 )
plt.loglog(PEnergy, StopPow,  label='DebyeLengthTotal')
plt.loglog(PEnergy1, StopPow1,  label='DebyeLengthE')
plt.xlim(0.1, 16)
plt.ylim(0.001, 0.18)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="700">
