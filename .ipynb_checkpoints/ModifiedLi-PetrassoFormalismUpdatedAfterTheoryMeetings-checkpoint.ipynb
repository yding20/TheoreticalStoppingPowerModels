# %%
# %matplotlib notebook
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import integrate
from LPModelCouplingGamaGeneracyTheta import *

X_axis_4MeV = [4]
#Y_axis_4MeV = [0.072, 0.074, 0.085, 0.089, 0.084, 0.081, 0.086, 0.075, 0.073, 0.083] 
Y_axis_4MeV = [0.08882, 0.0911, 0.0945, 0.0939, 0.0921, 0.08621] # line 252

X_axis_3_5MeV = [3.5]
#Y_axis_3_5MeV = [0.081, 0.083, 0.096, 0.101, 0.094, 0.091, 0.0967, 0.084, 0.083, 0.093]
Y_axis_3_5MeV = [0.1006, 0.1032, 0.10645, 0.1082, 0.103, 0.09708]
                 
X_axis_3MeV = [3]
#Y_axis_3MeV = [0.093, 0.095, 0.110, 0.116, 0.109, 0.104, 0.111, 0.097, 0.095, 0.107]
Y_axis_3MeV = [0.1148, 0.1182, 0.1206, 0.1228, 0.119, 0.1146]

X_axis_2_5MeV = [2.5]
#Y_axis_2_5MeV = [0.109, 0.112, 0.130, 0.136, 0.127, 0.122, 0.129, 0.1138, 0.112, 0.125]
Y_axis_2_5MeV = [0.1348, 0.1386, 0.1397, 0.1418, 0.140, 0.1318]

X_axis_2MeV = [2]
#Y_axis_2MeV = [0.131, 0.135, 0.156, 0.164, 0.152, 0.146, 0.156, 0.136, 0.134, 0.151] 
Y_axis_2MeV = [0.16396]

X_axis_1_5MeV = [1.5]
#Y_axis_1_5MeV = [0.165, 0.170, 0.198, 0.207, 0.191, 0.184, 0.197, 0.172, 0.169, 0.190]
Y_axis_1_5MeV = [0.20638]

X_axis_1MeV = [1]
#Y_axis_1MeV = [0.228, 0.263, 0.277, 0.286, 0.264, 0.256, 0.270, 0.238, 0.243, 0.259]
Y_axis_1MeV = [0.2733]

X_axis_05MeV = [0.5]
#Y_axis_05MeV = [0.332, 0.366, 0.424, 0.426, 0.391, 0.375, 0.397, 0.355, 0.359, 0.373]
Y_axis_05MeV = [0.401]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'b',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'b',markersize='5')

PEnergy, StopPow = LP(1, 0, FieldDensity=1, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1 = LP(1, 1, FieldDensity=1, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )

#plt.plot(PEnergy, StopPow, label='AlexThesis_1gcc_10eV')
plt.plot(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'g')
plt.xlim(0,4)
plt.ylim(0,1.0)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DegeneracyTheta = 0.9584480427768621 CoulpingGama = 0.6076463038710708
# DegeneracyTheta = 0.9584480427768621 CoulpingGama = 0.6076463038710708

# %%
X_axis_4MeV = [4]
#Y_axis_4MeV = [0.018, 0.0192, 0.0215, 0.02365, 0.0219, 0.0208, 0.0221, 0.0193, 0.01892, 0.02179]  # line 784
Y_axis_4MeV = [0.0229, 0.02323, 0.02475, 0.02407, 0.02409] ##line 275

X_axis_3_5MeV = [3.5]
#Y_axis_3_5MeV = [0.021, 0.0218, 0.0244, 0.02682, 0.02480, 0.0235, 0.025, 0.0219, 0.02134, 0.02469]
Y_axis_3_5MeV = [0.0260, 0.02619, 0.02795, 0.02727, 0.02705]

X_axis_3MeV = [3]
#Y_axis_3MeV = [0.024, 0.0252, 0.0282, 0.03098, 0.02869, 0.0271, 0.0288, 0.02527, 0.02470, 0.02848]
Y_axis_3MeV = [0.0300, 0.03021, 0.03215, 0.03151, 0.03101]
               
X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.028, 0.0297, 0.0333, 0.03660, 0.03371, 0.0320, 0.0340, 0.02985, 0.02918, 0.03362]
Y_axis_2_5MeV = [0.0354, 0.03570, 0.03773, 0.03713, 0.03641]

X_axis_2MeV = [2]
#Y_axis_2MeV = [0.035, 0.036, 0.041, 0.045, 0.041,0.039, 0.041, 0.036, 0.035, 0.041]
Y_axis_2MeV = [0.04316, 0.0436]   # line 79

X_axis_1_5MeV = [1.5]
#Y_axis_1_5MeV = [0.045, 0.047, 0.053, 0.058, 0.053, 0.050, 0.053, 0.047, 0.046, 0.053]
Y_axis_1_5MeV = [0.05535, 0.0561]

X_axis_1MeV = [1]
#Y_axis_1MeV = [0.063, 0.065, 0.074, 0.081, 0.073, 0.070, 0.075, 0.065, 0.0649, 0.074]
Y_axis_1MeV = [0.07698, 0.0780]

X_axis_05MeV = [0.5]
#Y_axis_05MeV = [0.105, 0.109, 0.127, 0.135, 0.121,0.115, 0.126, 0.105, 0.108, 0.123]
Y_axis_05MeV = [0.13204, 0.124]

X_axis_025MeV = [0.25]
Y_axis_025MeV = [0.162]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'b',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_025MeV = 0.25
Y_average_025MeV = np.sum(Y_axis_025MeV)/len(Y_axis_025MeV)
plt.errorbar(X_average_025MeV, Y_average_025MeV, np.std (Y_axis_025MeV),marker='o',capsize=3,c = 'g',markersize='5')

PEnergy, StopPow = LP(1, 0, FieldDensity=0.25, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1 = LP(1, 1, FieldDensity=0.25, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )

#plt.plot(PEnergy, StopPow, label='AlexThesis_0.25gcc_10eV')
plt.plot(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'g')
plt.xlim(0,4)
plt.ylim(0,0.35)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DegeneracyTheta = 2.415137728650221 CoulpingGama = 0.5531480117081214
# DegeneracyTheta = 2.415137728650221 CoulpingGama = 0.5531480117081214

# %%
X_axis_4MeV = [4]
Y_axis_4MeV = [0.00471]

X_axis_3_5MeV = [3.5]
Y_axis_3_5MeV = [0.00533]

X_axis_3MeV = [3]
Y_axis_3MeV = [0.047]

X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.050]

X_axis_2MeV = [2]
Y_axis_2MeV = [0.045]

X_axis_1_5MeV = [1.5]
Y_axis_1_5MeV = [0.045, 0.047, 0.053, 0.058, 0.053, 0.050, 0.053, 0.047, 0.046, 0.053]

X_axis_1MeV = [1]
Y_axis_1MeV = [0.063, 0.065, 0.074, 0.081, 0.073, 0.070, 0.075, 0.065, 0.0649, 0.074]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [0.105, 0.109, 0.127, 0.135, 0.121,0.115, 0.126, 0.105, 0.108, 0.123]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'b',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'b',markersize='5')

PEnergy, StopPow = LP(1, 0, FieldDensity=0.05, FieldTem=50, FieldCharge=1, FieldMass=3, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1 = LP(1, 1, FieldDensity=0.05, FieldTem=50, FieldCharge=1, FieldMass=3, ProjE=4, ProjM=4, ProjC=2 )

plt.plot(PEnergy, StopPow, label='AlexThesis')
plt.plot(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'g')
plt.xlim(0,4)
plt.ylim(0,0.04)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DegeneracyTheta = 39.8730453803182 CoulpingGama = 0.08398395666086085
# DegeneracyTheta = 39.8730453803182 CoulpingGama = 0.08398395666086085

# %%
plt.savefig('DT.25gcc32eV.pdf')

# %%
(0.4**5)+(5*0.6*0.4**4)+(10*0.6**2*0.4**3)+(10*0.6**3*0.4**2)+(5*0.6**4*0.4)+(0.6**5)
# Out:
# 1.0
