# %%
# %matplotlib notebook
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import integrate
from LPModelCouplingGamaGeneracyTheta import *
import matplotlib.ticker as ticker

X_axis_4MeV = [4]
Y_axis_4MeV = [0.08882, 0.0911, 0.0945, 0.0939, 0.0921, 0.08621, 0.09243, 0.09082, 0.0896, 0.0944, 0.0901, 0.095, 0.097, 
              0.0937, 0.092, 0.085] 

X_axis_3_5MeV = [3.5]
Y_axis_3_5MeV = [0.1006, 0.1032, 0.10645, 0.1082, 0.103, 0.09708, 0.1044, 0.1018, 0.102, 0.106, 0.1023, 0.1075, 0.111,
                0.1066, 0.105, 0.095]
                 
X_axis_3MeV = [3]
Y_axis_3MeV = [0.1148, 0.1182, 0.1206, 0.1228, 0.119, 0.1146, 0.119, 0.116, 0.117, 0.121, 0.118, 0.122, 0.126, 
              0.1228, 0.120, 0.109]

X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.1348, 0.1386, 0.1397, 0.1418, 0.140, 0.1318, 0.138, 0.1365, 0.136, 0.142, 0.138, 0.147, 
                0.1447, 0.142, 0.128]

X_axis_2MeV = [2]
Y_axis_2MeV = [0.16396, 0.1677, 0.168, 0.172, 0.171, 0.161, 0.166, 0.171, 0.162, 0.155, 0.162, 0.142]

X_axis_1_5MeV = [1.5]
Y_axis_1_5MeV = [0.20638, 0.2008, 0.213, 0.218, 0.203, 0.206, 0.216, 0.202, 0.195, 0.205]

X_axis_1MeV = [1]
Y_axis_1MeV = [0.2733, 0.25145, 0.271, 0.270, 0.278, 0.254, 0.257, 0.269, 0.249, 0.250, 0.265]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [0.366, 0.333, 0.3667, 0.425, 0.426, 0.391,  0.375,  0.397,  0.355, 0.395,  0.373]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'r',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'r',markersize='5')

PEnergy, StopPow, LratioLP = LP(1, 1, FieldDensity=1, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )

plt.semilogy(PEnergy, StopPow, '--', label='Li_Petrasso_Model' ,c = 'g')

data4 = np.genfromtxt('dedx_DT1.out')
x4 = data4[:,1] * 1.e-3 # [mu-m] cm * 10^4 = micron
dedx4 = data4[:,2]     # [MeV/mu-m]
dedxi4 = data4[:,3]    # [MeV/mu-m]
edxe4 = data4[:,4]  # [MeV/mu-m]

plt.semilogy(x4,dedx4, c = 'r',label='BPS')

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))


y = np.array([10**(-1),10**(-0.8),10**(-0.6),10**(-0.4),10**(-0.2),10**(-0.0)])
my_xticks = ['$10^{-1}$', '$10^{-0.8}$', '$10^{-0.6}$', '$10^{-0.4}$','$10^{-0.2}$','$10^{-0.0}$']
plt.yticks(y, my_xticks)

plt.xlim(0,4)
plt.ylim(0.08,1.0)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.title('DT1gcc10eV')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DegeneracyTheta = 0.7117954772721771 CoulpingGama = 0.5991069599728676

# %%
import matplotlib.ticker as ticker
X_axis_4MeV = [4]
Y_axis_4MeV = [0.0229, 0.02323, 0.02475, 0.02407, 0.02409, 0.02262] ##line 275

X_axis_3_5MeV = [3.5]
Y_axis_3_5MeV = [0.0260, 0.02619, 0.02795, 0.02727, 0.02705, 0.02537]

X_axis_3MeV = [3]
Y_axis_3MeV = [0.0300, 0.03021, 0.03215, 0.03151, 0.03101, 0.02899]
               
X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.0354, 0.03570, 0.03773, 0.03713, 0.03641, 0.03387]

X_axis_2MeV = [2]
Y_axis_2MeV = [0.04316, 0.0436, 0.04552, 0.04502, 0.0412, 0.0443]  

X_axis_1_5MeV = [1.5]
Y_axis_1_5MeV = [0.05535, 0.0561, 0.05756, 0.05776, 0.0538, 0.0574]

X_axis_1MeV = [1]
Y_axis_1MeV = [0.07698, 0.0780, 0.07970, 0.08085, 0.0754, 0.0807]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [0.13204, 0.124, 0.125, 0.124, 0.1191, 0.0126]

X_axis_025MeV = [0.25]
Y_axis_025MeV = [0.162]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'r',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_025MeV = 0.25
Y_average_025MeV = np.sum(Y_axis_025MeV)/len(Y_axis_025MeV)
plt.errorbar(X_average_025MeV, Y_average_025MeV, np.std (Y_axis_025MeV),marker='o',capsize=3,c = 'r',markersize='5')

PEnergy, StopPow, LratioLP = LP(1, 0, FieldDensity=0.25, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1, LratioLP1 = LP(1, 1, FieldDensity=0.25, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )


#plt.plot(PEnergy, StopPow, label='AlexThesis_0.25gcc_10eV')
plt.plot(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'b')

data4 = np.genfromtxt('dedx_DT0.25.out')
x4 = data4[:,1] * 1.e-3 # [mu-m] cm * 10^4 = micron
dedx4 = data4[:,2]     # [MeV/mu-m]
dedxi4 = data4[:,3]    # [MeV/mu-m]
edxe4 = data4[:,4]  # [MeV/mu-m]

plt.semilogy(x4,dedx4, c = 'g',label='BPS')
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))


y = np.array([10**(-1.6),10**(-1.4),10**(-1.2),10**(-1.0),10**(-0.8),10**(-0.6),10**(-0.4)])
my_xticks = ['$10^{-1.6}$', '$10^{-1.4}$', '$10^{-1.2}$', '$10^{-1.0}$','$10^{-0.8}$', '$10^{-0.6}$',  '$10^{-0.4}$', 
             '$10^{2.0}$', '$10^{2.2}$']
plt.yticks(y, my_xticks)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.xlim(0,4)
plt.ylim(0.02,0.35)
plt.title('DT0.25gcc10eV')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DegeneracyTheta = 1.7936122100703673 CoulpingGama = 0.5827426211790276
# DegeneracyTheta = 1.7936122100703673 CoulpingGama = 0.5827426211790276

# %%
plt.savefig('DT1gcc32eV.pdf')

# %%
1/(1.6726219e-24*2.5)
# Out:
# 2.391454996493828e+23
