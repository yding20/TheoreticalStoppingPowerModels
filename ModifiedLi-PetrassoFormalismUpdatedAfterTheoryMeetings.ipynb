# %%
# %matplotlib notebook
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import integrate
from LPModelCouplingGamaGeneracyTheta import *
import matplotlib.ticker as ticker

X_axis_4MeV = [4]
Y_axis_4MeV = [0.08882, 0.0911, 0.0945, 0.0939, 0.0921, 0.08621] # line 252

X_axis_3_5MeV = [3.5]
Y_axis_3_5MeV = [0.1006, 0.1032, 0.10645, 0.1082, 0.103, 0.09708]
                 
X_axis_3MeV = [3]
Y_axis_3MeV = [0.1148, 0.1182, 0.1206, 0.1228, 0.119, 0.1146]

X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.1348, 0.1386, 0.1397, 0.1418, 0.140, 0.1318]

X_axis_2MeV = [2]
Y_axis_2MeV = [0.16396, 0.1677, 0.168, 0.172, 0.171, 0.161, 0.166, 0.171, 0.162, 0.155, 0.162]

X_axis_1_5MeV = [1.5]
Y_axis_1_5MeV = [0.20638, 0.2008, 0.213, 0.218, 0.203, 0.206, 0.216, 0.202, 0.195, 0.205]

X_axis_1MeV = [1]
Y_axis_1MeV = [0.2733, 0.25145, 0.271, 0.270, 0.278, 0.254, 0.257, 0.269, 0.249, 0.250, 0.265]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [ 0.305, 0.308, 0.315, 0.320, 0.268, 0.302, 0.325, 0.254, 0.283, 0.325]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'r',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'r',markersize='5')

PEnergy, StopPow = LP(1, 0, FieldDensity=1, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1 = LP(1, 1, FieldDensity=1, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )

#plt.plot(PEnergy, StopPow, label='AlexThesis_1gcc_10eV')
plt.semilogy(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'b')
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))


y = np.array([10**(-1),10**(-0.8),10**(-0.6),10**(-0.4),10**(-0.2),10**(-0.0)])
my_xticks = ['$10^{-1}$', '$10^{-0.8}$', '$10^{-0.6}$', '$10^{-0.4}$','$10^{-0.2}$','$10^{-0.0}$']
plt.yticks(y, my_xticks)
plt.xlim(0,4)
plt.ylim(0,1.0)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.title('DT1gcc10eV')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DegeneracyTheta = 0.9584480427768621 CoulpingGama = 0.6076463038710708
# DegeneracyTheta = 0.9584480427768621 CoulpingGama = 0.6076463038710708

# %%
import matplotlib.ticker as ticker
X_axis_4MeV = [4]
Y_axis_4MeV = [0.0229, 0.02323, 0.02475, 0.02407, 0.02409, 0.02262] ##line 275

X_axis_3_5MeV = [3.5]
Y_axis_3_5MeV = [0.0260, 0.02619, 0.02795, 0.02727, 0.02705, 0.02537]

X_axis_3MeV = [3]
Y_axis_3MeV = [0.0300, 0.03021, 0.03215, 0.03151, 0.03101, 0.02899]
               
X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.0354, 0.03570, 0.03773, 0.03713, 0.03641, 0.03387]

X_axis_2MeV = [2]
Y_axis_2MeV = [0.04316, 0.0436, 0.04552, 0.04502]   # line 79

X_axis_1_5MeV = [1.5]
Y_axis_1_5MeV = [0.05535, 0.0561, 0.05756, 0.05776]
g
X_axis_1MeV = [1]
Y_axis_1MeV = [0.07698, 0.0780, 0.07970, 0.08085]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [0.13204, 0.124, 0.125, 0.124]

X_axis_025MeV = [0.25]
Y_axis_025MeV = [0.162]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'r',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'r',markersize='5')

X_average_025MeV = 0.25
Y_average_025MeV = np.sum(Y_axis_025MeV)/len(Y_axis_025MeV)
plt.errorbar(X_average_025MeV, Y_average_025MeV, np.std (Y_axis_025MeV),marker='o',capsize=3,c = 'r',markersize='5')

PEnergy, StopPow = LP(1, 0, FieldDensity=0.25, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1 = LP(1, 1, FieldDensity=0.25, FieldTem=10, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )


#plt.plot(PEnergy, StopPow, label='AlexThesis_0.25gcc_10eV')
plt.semilogy(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'b')
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))


y = np.array([10**(-1.6),10**(-1.4),10**(-1.2),10**(-1.0),10**(-0.8),10**(-0.6),10**(-0.4)])
my_xticks = ['$10^{-1.6}$', '$10^{-1.4}$', '$10^{-1.2}$', '$10^{-1.0}$','$10^{-0.8}$', '$10^{-0.6}$',  '$10^{-0.4}$', 
             '$10^{2.0}$', '$10^{2.2}$']
plt.yticks(y, my_xticks)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.xlim(0,4)
plt.ylim(0,0.35)
plt.title('DT0.25gcc10eV')
plt.legend()
# Out:
# DegeneracyTheta = 2.415137728650221 CoulpingGama = 0.5531480117081214
# DegeneracyTheta = 2.415137728650221 CoulpingGama = 0.5531480117081214

# %%
X_axis_4MeV = [4]
Y_axis_4MeV = [0.0052]

X_axis_3_5MeV = [3.5]
Y_axis_3_5MeV = [0.00539]

X_axis_3MeV = [3]
Y_axis_3MeV = [0.00628]

X_axis_2_5MeV = [2.5]
Y_axis_2_5MeV = [0.00762]

X_axis_2MeV = [2]
Y_axis_2MeV = [0.045]

X_axis_1_5MeV = [1.5]
Y_axis_1_5MeV = [0.045, 0.047, 0.053, 0.058, 0.053, 0.050, 0.053, 0.047, 0.046, 0.053]

X_axis_1MeV = [1]
Y_axis_1MeV = [0.063, 0.065, 0.074, 0.081, 0.073, 0.070, 0.075, 0.065, 0.0649, 0.074]

X_axis_05MeV = [0.5]
Y_axis_05MeV = [0.105, 0.109, 0.127, 0.135, 0.121,0.115, 0.126, 0.105, 0.108, 0.123]

X_average_4MeV = 4
Y_average_4MeV = np.sum(Y_axis_4MeV)/len(Y_axis_4MeV)
plt.errorbar(X_average_4MeV, Y_average_4MeV, np.std (Y_axis_4MeV),marker='o',capsize=3,c = 'b',markersize='5',
            label='TD-OF-DFT')

X_average_3_5MeV = 3.5
Y_average_3_5MeV = np.sum(Y_axis_3_5MeV)/len(Y_axis_3_5MeV)
plt.errorbar(X_average_3_5MeV, Y_average_3_5MeV, np.std (Y_axis_3_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_3MeV = 3
Y_average_3MeV = np.sum(Y_axis_3MeV)/len(Y_axis_3MeV)
plt.errorbar(X_average_3MeV, Y_average_3MeV, np.std (Y_axis_3MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2_5MeV = 2.5
Y_average_2_5MeV = np.sum(Y_axis_2_5MeV)/len(Y_axis_2_5MeV)
plt.errorbar(X_average_2_5MeV, Y_average_2_5MeV, np.std (Y_axis_2_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_2MeV = 2
Y_average_2MeV = np.sum(Y_axis_2MeV)/len(Y_axis_2MeV)
plt.errorbar(X_average_2MeV, Y_average_2MeV, np.std (Y_axis_2MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1_5MeV = 1.5
Y_average_1_5MeV = np.sum(Y_axis_1_5MeV)/len(Y_axis_1_5MeV)
plt.errorbar(X_average_1_5MeV, Y_average_1_5MeV, np.std (Y_axis_1_5MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_1MeV = 1
Y_average_1MeV = np.sum(Y_axis_1MeV)/len(Y_axis_1MeV)
plt.errorbar(X_average_1MeV, Y_average_1MeV, np.std (Y_axis_1MeV),marker='o',capsize=3,c = 'b',markersize='5')

X_average_05MeV = 0.5
Y_average_05MeV = np.sum(Y_axis_05MeV)/len(Y_axis_05MeV)
plt.errorbar(X_average_05MeV, Y_average_05MeV, np.std (Y_axis_05MeV),marker='o',capsize=3,c = 'b',markersize='5')

PEnergy, StopPow = LP(1, 0, FieldDensity=0.05, FieldTem=50, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )
PEnergy1, StopPow1 = LP(1, 1, FieldDensity=0.05, FieldTem=50, FieldCharge=1, FieldMass=2.5, ProjE=4, ProjM=4, ProjC=2 )

plt.plot(PEnergy, StopPow, label='AlexThesis')
plt.plot(PEnergy1, StopPow1, '--', label='Li_Petrasso_Model' ,c = 'g')
plt.xlim(0,4)
plt.ylim(0,0.05)
plt.xlabel('Projectile Energy(MeV)')
plt.ylabel('Stopping power -dE/dx (Mev/um)')
plt.legend()
# Out:
# DegeneracyTheta = 35.30952779400189 CoulpingGama = 0.08896495822058904
# DegeneracyTheta = 35.30952779400189 CoulpingGama = 0.08896495822058904

# %%
plt.savefig('DT1gcc32eV.pdf')
